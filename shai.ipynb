# %% [markdown]
# #About Dataset
# salaries dataset generally provides information about the employees of an organization in relation to their compensation. It typically includes details such as how much each employee is paid (their salary), their job titles, the departments they work in, and possibly additional information like their level of experience, education, and employment history within the organization.

# %% [markdown]
# # About Features
#
# 1. **Employee ID**: A unique identifier for each employee. Usually a numeric or alphanumeric code.
#
# 2. **Name**: The full name of the employee. This might be split into first and last names in some datasets.
#
# 3. **Department**: The department or division within the organization where the employee works.
#
# 4. **Job Title**: The official title or position held by the employee in the organization.
#
# 5. **Salary**: The amount of money the employee earns. This could be represented as an annual salary, hourly wage, or monthly pay.
#
# 6. **Hire Date**: The date when the employee started working at the organization. Useful for calculating tenure or experience.
#
# 7. **Gender**: The gender of the employee. This might be included in some datasets for diversity and equality analysis.
#
# 8. **Years of Experience**: The total number of years the employee has worked in their field or profession.
#
# 9. **Education Level**: The highest level of education attained by the employee, such as a high school diploma, bachelor's degree, etc.
#
# 10. **Performance Rating**: If available, this could be a measure of the employee's performance in their role, often based on annual review scores.
#
# 11. **Location**: The geographical location or office where the employee works, if the organization has multiple locations.

# %% [markdown]
# # Tasks
#
# 1. **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.
#
# 2. **Descriptive Statistics**: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.
#
# 3. **Data Cleaning**: Handle missing data by suitable method with explain why you use it.
#
# 4. **Basic Data Visualization**: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.
#
# 5. **Grouped Analysis**: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.
#
# 6. **Simple Correlation Analysis**: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.
#
# 8. **Summary of Insights**: Write a brief report summarizing the findings and insights from the analyses.

# %%
import pandas as pd
import numpy as np
import statistics
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('SalariesX.csv')
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency
# 0  2011    NaN  San Francisco
# ...

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency'],
#       dtype='object')

# %%
#Question 1 
print("The solution is : ") 
print("number of rows is:{} and the number of columns is:{}".format(df.shape[0],df.shape[1]))
print("**********************")
df.info()
print("**********************")
df.isnull().sum()
# Out:
# The solution is :
# number of rows is:148654 and the number of columns is:12
# **********************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
# dtypes: float64(7), int64(2), object(3)
# memory usage: 13.6+ MB
# ...

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
#Question 2
print("The solution is :")
print ("For all data")
df.describe()
print("For TotalPay column")
df['TotalPay'].describe() 
salary_range = np.max(df['TotalPay']) - np.min(df['TotalPay'])
median_salary = np.median(df['TotalPay'])
mode = statistics.mode(df['TotalPay'])
print("Median Salary:", median_salary)
print("Mode Salary:", mode)
print("Salary Range:", salary_range)
# Out:
# The solution is :
# For all data
# For TotalPay column
# Median Salary: 71426.60999999999
# Mode Salary: 0.0
# Salary Range: 568213.56

# %%
#Question3
#we delete notes column because it has 
del df['Notes']

# %%
df['BasePay'].fillna(0, inplace=True) 
df['OtherPay'].fillna(0, inplace=True) 
df['Benefits'].fillna(0, inplace=True)
df['OvertimePay'].fillna(0, inplace=True)
df.head()
df.isnull().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %%
#Question4
print("The solution is :")
plt.hist(df['TotalPayBenefits'], bins=10, color='blue', edgecolor='black')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.title('Salary Distribution')
plt.show()

# Create bar chart for department distribution
department_counts = df['JobTitle'].value_counts()
sums=department_counts
plt.bar(sums.index, sums.values, color='red')
plt.xlabel('JobTitle')
plt.ylabel('Number of Employees')
plt.title('Employee Distribution by Department')
plt.xticks(rotation=45)
plt.show()

# Create pie chart for proportion of employees in different departments
plt.pie(sums, labels=sums.index, autopct='%1.1f%%', startangle=600, colors=['silver', 'lightpink', 'blue', 'lightyellow'])
plt.axis('equal')
plt.title('Proportion of Employees in Different Departments')
plt.show()
#Due to the size of the large data, the drawing seems blurred, so I drew a small sample. 
# Create bar chart for department distribution
department_counts = df['JobTitle'].value_counts()
sums=department_counts.iloc[1:7]
plt.bar(sums.index, sums.values, color='lightgreen')
plt.xlabel('JobTitle')
plt.ylabel('Number of Employees')
plt.title('Employee Distribution by Department')
plt.xticks(rotation=45)
plt.show()

# Create pie chart for proportion of employees in different departments
plt.pie(sums, labels=sums.index, autopct='%1.1f%%', startangle=600, colors=['green', 'coral', 'lightskyblue', 'yellow'])
plt.axis('equal')
plt.title('Proportion of Employees in Different Departments')
plt.show()
# Out:
# The solution is :

# %%
#Question 5
import pandas as pd

# Group data by the selected column (or columns).
grouped_data = df.groupby(['EmployeeName', 'TotalPay'])

# Calculate summary statistics for each group
summary_stats = grouped_data['TotalPay'].mean()

# Print summary statistics
print(summary_stats)

# Compare average salaries between different groups
average_salaries = summary_stats.groupby('EmployeeName').mean()
print(average_salaries)
# Out:
# EmployeeName           TotalPay
# A BERNARD FATOOH       20039.91    20039.91
# A Bernard  Fatooh      23923.62    23923.62
# A Bernard Fatooh       18500.19    18500.19
#                        24061.35    24061.35
# A ELIZABETH MARCHASIN  26282.86    26282.86
#                                      ...
# Zuna T Luu             56087.91    56087.91
#                        56155.44    56155.44
# Zuri  Jones            71986.90    71986.90
# Zuri Jones             66667.54    66667.54
#                        86588.52    86588.52
# Name: TotalPay, Length: 148621, dtype: float64
# EmployeeName
# A BERNARD FATOOH         20039.910
# A Bernard  Fatooh        23923.620
# A Bernard Fatooh         21280.770
# A ELIZABETH MARCHASIN    26282.860
# A JAMIL NIAZI            87496.210
#                            ...
# Zun Jin Zhang He         57820.370
# Zuna Luu                 52518.080
# Zuna T Luu               56121.675
# Zuri  Jones              71986.900
# ...

# %%
#Question6
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset into a pandas dataframe
data = pd.read_csv('SalariesX.csv')

# Calculate the correlation between salary and another numerical column
correlation = df['TotalPay'].corr(df['TotalPayBenefits'])

# Plot a scatter plot to visualize the relationship
plt.scatter(df['TotalPay'], df['TotalPayBenefits'])
plt.title('TotalPay vs TotalPayBenefits')
plt.xlabel('TotalPay')
plt.ylabel('TotalPayBenefits')
plt.show()

print("Correlation between TotalPay and TotalPayBenefits:", correlation)
# Out:
# Correlation between TotalPay and TotalPayBenefits: 0.9773128522072128

# %% [markdown]
# #Question7
#
#
# pandas ,numpy,statistics,matplotlib.pyplot قمنا باستيراد المكتبات
#
# pd.read_csvقمنا بتحميل مجموعة البيانات وتخزينه بمتغير CSV باستخدام الدالة
#
# df.head()يتم عرض أول خمسة صفوف من مجموعة البيانات
#
# df.columns يتم عرض اسماء الأعمدة
# ________________________________________
# Qestion 1
#
# يتم طباعة عدد الصفوف وعدد الأعمدة ومعلومات حول مجموعة البيانات (انواع البيانات لكل عمود )وقمنا بطباعة عدد القيم الناقصة
#
# Question 2
#
# describe() : تشمل الإحصائيات الوصفية المتوسط والانحراف المعياري والقيم الدنيا والقيم العليا والنسب المئوية السفلية والمتوسطة والعليا
#
# min ,median,mode قمنا باستخدام توابع أخرى لحساب ال
#
# salary_range = np.max(df['TotalPay']) - np.min(df['TotalPay'])
#
# median_salary = np.median(df['TotalPay'])
#
# mode = statistics.mode(df['TotalPay'])
#
# Question 3
#
# del df['Notes'] :148654 قمنا بحذفه لانه يحتوي على
#
# df['OvertimePay'].fillna(0, inplace=True): بالقيمة 0"OvertimePay" هذا السطر يقوم بملء القيم الناقصة في عمود
#
# df['OtherPay'].fillna(0, inplace=True): بالقيمة 0"OtherPay" هذا السطر يقوم بملء القيم الناقصة في عمود
#
# df['Benefits'].fillna(0, inplace=True): بالقيمة 0"Benefits" هذا السطر يقوم بملء القيم الناقصة في عمود
#
# df.head(): هذا السطر يقوم بعرض الصفوف الأولى في البيانات
#
# df.isnull().sum(): هذا السطر يقوم بحساب عدد القيم الناقصة في كل عمود في البيانات
#
# حيث كان الخرج :
#
# Id 0
#
# EmployeeName 0
#
# JobTitle 0
#
# BasePay 0
#
# OvertimePay 0
#
# OtherPay 0
#
# Benefits 0
#
# TotalPay 0
#
# TotalPayBenefits 0
#
# Year 0
#
# Agency 0
#
# dtype: int64
#
# Qestion 4
#
# :الكود يتضمن ثلاثة أكواد مختلفة لإنشاء تصورات مختلفة للبيانات
#
# الكود الأول
#
# hist() : هذا التابع يقوم بإنشاء مخطط توزيع الرواتب
#
# bar() : يقوم بإنشاء مخطط شريطي لتوزيع الموظفين حسب الإدارة باستخدام الدالة
#
# value_counts() : لحساب عدد الموظفين في كل إدارة
#
# xticks(rotation=45) :تم تدوير تسميات المحاور بزاوية 45 درجة
#
# pie(): هذا الكود يقوم بإنشاء مخطط دائري لنسبة الموظفين في الإدارات المختلفة
#
# value_counts() :لحساب عدد الموظفين في كل إدارة .
#
# startangle() : تم تحديد زاوية البداية
#
# colors() : تحديد ألوان الأقسام
#
# وبسبب ان الداتا كبيرة لذلك قمنا بأخذ مجموعة من الداتا و رسمناها لكي نوضح الرسم
#
# Qestion 5
#
# لدينا الكود
#
# grouped_data = data.groupby(['EmployeeName', 'TotalPay'])
#
# summary_stats = grouped_data['TotalPay'].mean()
#
# print(summary_stats)
#
# average_salaries = summary_stats.groupby('EmployeeName').mean()
#
# print(average_salaries) لحساب الإحصائيات الملخصة لكل مجموعة ومقارنة المرتبات المتوسطة بين المجموعات المختلفة
#
# لتجميع البيانات حسب العمود (أو الأعمدة) المحددة groupby استخدمنا
#
# قارنا المرتبات المتوسطة بين المجموعات المختلفة
#
# ___________________________________________________
#
# Qestion 6
#
# ورسمنا مخطط مبعثر لتصور العلاقة بينهما TotalPay,TotalPayBenefits قمنا بتحدد ارتباط بين
